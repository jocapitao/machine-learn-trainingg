# %%
import pandas as pd
import numpy as np

# %%
#airports = pd.read_csv('flights/flights.csv')
#flights[:1000000].to_csv('flights/flights_subset.csv') # save a subset

airports = pd.read_csv('flights/airports.csv')
flights = pd.read_csv( 'flights/flights_subset.csv')

# %%
#airports.to_excel?


airports.to_excel("my_airports_analysis.xlsx")  # saves where you are working with your notebook

# %%
airports.head()
# Out:
#   IATA_CODE                              AIRPORT         CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport    Allentown    PA     USA
# 1       ABI             Abilene Regional Airport      Abilene    TX     USA
# 2       ABQ    Albuquerque International Sunport  Albuquerque    NM     USA
# 3       ABR            Aberdeen Regional Airport     Aberdeen    SD     USA
# 4       ABY   Southwest Georgia Regional Airport       Albany    GA     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236  -75.44040
# 1  32.41132  -99.68190
# 2  35.04022 -106.60919
# 3  45.44906  -98.42183
# 4  31.53552  -84.19447

# %%
airports.tail()
# Out:
#     IATA_CODE                              AIRPORT  \
# 317       WRG                     Wrangell Airport
# 318       WYS               Westerly State Airport
# 319       XNA  Northwest Arkansas Regional Airport
# 320       YAK                      Yakutat Airport
# 321       YUM           Yuma International Airport
#
#                                CITY STATE COUNTRY  LATITUDE  LONGITUDE
# 317                        Wrangell    AK     USA  56.48433 -132.36982
# 318                West Yellowstone    MT     USA  44.68840 -111.11764
# 319  Fayetteville/Springdale/Rogers    AR     USA  36.28187  -94.30681
# 320                         Yakutat    AK     USA  59.50336 -139.66023
# 321                            Yuma    AZ     USA  32.65658 -114.60597

# %%
airports.head(1)
# Out:
#   IATA_CODE                              AIRPORT       CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport  Allentown    PA     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236   -75.4404

# %%
airports.shape
# Out:
# (322, 7)

# %%
airports.columns
# Out:
# Index(['IATA_CODE', 'AIRPORT', 'CITY', 'STATE', 'COUNTRY', 'LATITUDE',
#        'LONGITUDE'],
#       dtype='object')

# %%
airports.dtypes
# Out:
# IATA_CODE     object
# AIRPORT       object
# CITY          object
# STATE         object
# COUNTRY       object
# LATITUDE     float64
# LONGITUDE    float64
# dtype: object

# %%
airports.describe()
# Out:
#          LATITUDE   LONGITUDE
# count  319.000000  319.000000
# mean    38.981244  -98.378964
# std      8.616736   21.523492
# min     13.483450 -176.646030
# 25%     33.652040 -110.839385
# 50%     39.297610  -93.403070
# 75%     43.154675  -82.722995
# max     71.285450  -64.798560

# %%
airports[['IATA_CODE', 'AIRPORT', 'CITY', 'STATE', 'COUNTRY']].describe()
# Out:
#        IATA_CODE                                            AIRPORT     CITY  \
# count        322                                                322      322
# unique       322                                                322      308
# top          CMI  Cincinnati/Northern Kentucky International Air...  Chicago
# freq           1                                                  1        2
#
#        STATE COUNTRY
# count    322     322
# unique    54       1
# top       TX     USA
# freq      24     322

# %%
airports.transpose().head(5)
# Out:
#                                            0                         1    \
# IATA_CODE                                  ABE                       ABI
# AIRPORT    Lehigh Valley International Airport  Abilene Regional Airport
# CITY                                 Allentown                   Abilene
# STATE                                       PA                        TX
# COUNTRY                                    USA                       USA
#
#                                          2                          3    \
# IATA_CODE                                ABQ                        ABR
# AIRPORT    Albuquerque International Sunport  Aberdeen Regional Airport
# CITY                             Albuquerque                   Aberdeen
# STATE                                     NM                         SD
# COUNTRY                                  USA                        USA
#
#                                           4                           5    \
# IATA_CODE                                 ABY                         ACK
# AIRPORT    Southwest Georgia Regional Airport  Nantucket Memorial Airport
# CITY                                   Albany                   Nantucket
# STATE                                      GA                          MA
# COUNTRY                                   USA                         USA
#
#                              6               7    \
# IATA_CODE                    ACT             ACV
# AIRPORT    Waco Regional Airport  Arcata Airport
# CITY                        Waco   Arcata/Eureka
# STATE                         TX              CA
# COUNTRY                      USA             USA
#
#                                            8             9    ...  \
# IATA_CODE                                  ACY           ADK  ...
# AIRPORT    Atlantic City International Airport  Adak Airport  ...
# CITY                             Atlantic City          Adak  ...
# STATE                                       NJ            AK  ...
# COUNTRY                                    USA           USA  ...
#
#                             312  \
# IATA_CODE                   TYS
# AIRPORT    McGhee Tyson Airport
# CITY                  Knoxville
# STATE                        TN
# COUNTRY                     USA
#
#                                                          313             314  \
# IATA_CODE                                                UST             VEL
# AIRPORT    Northeast Florida Regional Airport (St. August...  Valdez Airport
# CITY                                           St. Augustine          Vernal
# STATE                                                     FL              UT
# COUNTRY                                                  USA             USA
#
#                                  315  \
# IATA_CODE                        VLD
# AIRPORT    Valdosta Regional Airport
# CITY                        Valdosta
# STATE                             GA
# COUNTRY                          USA
#
#                                                   316               317  \
# IATA_CODE                                         VPS               WRG
# AIRPORT    Destin-Fort Walton Beach Airport/Eglin AFB  Wrangell Airport
# CITY                                       Valparaiso          Wrangell
# STATE                                              FL                AK
# COUNTRY                                           USA               USA
#
#                               318                                  319  \
# IATA_CODE                     WYS                                  XNA
# AIRPORT    Westerly State Airport  Northwest Arkansas Regional Airport
# CITY             West Yellowstone       Fayetteville/Springdale/Rogers
# STATE                          MT                                   AR
# COUNTRY                       USA                                  USA
#
#                        320                         321
# IATA_CODE              YAK                         YUM
# AIRPORT    Yakutat Airport  Yuma International Airport
# CITY               Yakutat                        Yuma
# STATE                   AK                          AZ
# COUNTRY                USA                         USA
#
# [5 rows x 322 columns]

# %%
airports_index = pd.read_csv('flights/airports.csv', index_col="IATA_CODE")

# %%
airports_index.head(5)
# Out:
#                                        AIRPORT         CITY STATE COUNTRY  \
# IATA_CODE
# ABE        Lehigh Valley International Airport    Allentown    PA     USA
# ABI                   Abilene Regional Airport      Abilene    TX     USA
# ABQ          Albuquerque International Sunport  Albuquerque    NM     USA
# ABR                  Aberdeen Regional Airport     Aberdeen    SD     USA
# ABY         Southwest Georgia Regional Airport       Albany    GA     USA
#
#            LATITUDE  LONGITUDE
# IATA_CODE
# ABE        40.65236  -75.44040
# ABI        32.41132  -99.68190
# ABQ        35.04022 -106.60919
# ABR        45.44906  -98.42183
# ABY        31.53552  -84.19447

# %%
airports['CITY'].head(5)
# Out:
# 0      Allentown
# 1        Abilene
# 2    Albuquerque
# 3       Aberdeen
# 4         Albany
# Name: CITY, dtype: object

# %%
airports[['CITY', 'COUNTRY']].head(5)
# Out:
#           CITY COUNTRY
# 0    Allentown     USA
# 1      Abilene     USA
# 2  Albuquerque     USA
# 3     Aberdeen     USA
# 4       Albany     USA

# %%
flights[['ARRIVAL_TIME', 'ARRIVAL_DELAY']].head(2)
# Out:
#    ARRIVAL_TIME  ARRIVAL_DELAY
# 0         408.0          -22.0
# 1         741.0           -9.0

# %%
round(flights['ARRIVAL_TIME'].mean(), 2)
# Out:
# 1492.77

# %%
flights[['ARRIVAL_TIME']].mean().round(2)
# Out:
# ARRIVAL_TIME    1492.77
# dtype: float64

# %%
flights[['ARRIVAL_TIME', 'ARRIVAL_DELAY']].mean().round(2)
# Out:
# ARRIVAL_TIME     1492.77
# ARRIVAL_DELAY       7.90
# dtype: float64

# %%
airports.head(2)
# Out:
#   IATA_CODE                              AIRPORT       CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport  Allentown    PA     USA
# 1       ABI             Abilene Regional Airport    Abilene    TX     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236   -75.4404
# 1  32.41132   -99.6819

# %%
airports[airports.STATE == 'PA'].head(2)
# Out:
#    IATA_CODE                                      AIRPORT  \
# 0        ABE          Lehigh Valley International Airport
# 24       AVP  Wilkes-Barre/Scranton International Airport
#
#                      CITY STATE COUNTRY  LATITUDE  LONGITUDE
# 0               Allentown    PA     USA  40.65236  -75.44040
# 24  Wilkes-Barre/Scranton    PA     USA  41.33815  -75.72427

# %%
#airports['CITY'].unique()

# %%
flights.head()
# Out:
#    Unnamed: 0  YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER  \
# 0           0  2015      1    1            4      AS             98
# 1           1  2015      1    1            4      AA           2336
# 2           2  2015      1    1            4      US            840
# 3           3  2015      1    1            4      AA            258
# 4           4  2015      1    1            4      AS            135
#
#   TAIL_NUMBER ORIGIN_AIRPORT DESTINATION_AIRPORT  ...  ARRIVAL_TIME  \
# 0      N407AS            ANC                 SEA  ...         408.0
# 1      N3KUAA            LAX                 PBI  ...         741.0
# 2      N171US            SFO                 CLT  ...         811.0
# 3      N3HYAA            LAX                 MIA  ...         756.0
# 4      N527AS            SEA                 ANC  ...         259.0
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# 0          -22.0         0          0                  NaN               NaN
# 1           -9.0         0          0                  NaN               NaN
# 2            5.0         0          0                  NaN               NaN
# 3           -9.0         0          0                  NaN               NaN
# 4          -21.0         0          0                  NaN               NaN
#
#    SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# 0             NaN            NaN                  NaN            NaN
# 1             NaN            NaN                  NaN            NaN
# 2             NaN            NaN                  NaN            NaN
# 3             NaN            NaN                  NaN            NaN
# 4             NaN            NaN                  NaN            NaN
#
# [5 rows x 32 columns]

# %%
flights[flights.ARRIVAL_TIME<100][['ARRIVAL_TIME', 'ARRIVAL_DELAY']].head(2)
# Out:
#       ARRIVAL_TIME  ARRIVAL_DELAY
# 4376          12.0          264.0
# 6063          32.0          512.0

# %%
flights['boolean_cond'] = [True if x < 100 else False for x in flights['ARRIVAL_TIME']]

# %%
flights[['ARRIVAL_TIME', 'boolean_cond']].head(20)
# Out:
#     ARRIVAL_TIME  boolean_cond
# 0          408.0         False
# 1          741.0         False
# 2          811.0         False
# 3          756.0         False
# 4          259.0         False
# 5          610.0         False
# 6          509.0         False
# 7          753.0         False
# 8          532.0         False
# 9          656.0         False
# 10         453.0         False
# 11         753.0         False
# 12         605.0         False
# 13         553.0         False
# 14         557.0         False
# 15         455.0         False
# 16         451.0         False
# 17         619.0         False
# 18         507.0         False
# 19         551.0         False

# %%
airports.head(2)
# Out:
#   IATA_CODE                              AIRPORT       CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport  Allentown    PA     USA
# 1       ABI             Abilene Regional Airport    Abilene    TX     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236   -75.4404
# 1  32.41132   -99.6819

# %%
airports.drop(1).head(2)
# Out:
#   IATA_CODE                              AIRPORT         CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport    Allentown    PA     USA
# 2       ABQ    Albuquerque International Sunport  Albuquerque    NM     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236  -75.44040
# 2  35.04022 -106.60919

# %%
airports.drop('IATA_CODE', axis=1).head(2)
# Out:
#                                AIRPORT       CITY STATE COUNTRY  LATITUDE  \
# 0  Lehigh Valley International Airport  Allentown    PA     USA  40.65236
# 1             Abilene Regional Airport    Abilene    TX     USA  32.41132
#
#    LONGITUDE
# 0   -75.4404
# 1   -99.6819

# %%
airports.drop(1, axis=0).head(2)
# Out:
#   IATA_CODE                              AIRPORT         CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport    Allentown    PA     USA
# 2       ABQ    Albuquerque International Sunport  Albuquerque    NM     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236  -75.44040
# 2  35.04022 -106.60919

# %%
airports.iloc[[0]].head(2)
# Out:
#   IATA_CODE                              AIRPORT       CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport  Allentown    PA     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236   -75.4404

# %%
airports.iloc[[1]].head(2)
# Out:
#   IATA_CODE                   AIRPORT     CITY STATE COUNTRY  LATITUDE  \
# 1       ABI  Abilene Regional Airport  Abilene    TX     USA  32.41132
#
#    LONGITUDE
# 1   -99.6819

# %%
airports.iloc[[0,1]].head(2)
# Out:
#   IATA_CODE                              AIRPORT       CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport  Allentown    PA     USA
# 1       ABI             Abilene Regional Airport    Abilene    TX     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236   -75.4404
# 1  32.41132   -99.6819

# %%
airports.head(2)
# Out:
#   IATA_CODE                              AIRPORT       CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport  Allentown    PA     USA
# 1       ABI             Abilene Regional Airport    Abilene    TX     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236   -75.4404
# 1  32.41132   -99.6819

# %%
airports['SOURCE'] = 'Kaggle'

# %%
airports.head(2)
# Out:
#   IATA_CODE                              AIRPORT       CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport  Allentown    PA     USA
# 1       ABI             Abilene Regional Airport    Abilene    TX     USA
#
#    LATITUDE  LONGITUDE  SOURCE
# 0  40.65236   -75.4404  Kaggle
# 1  32.41132   -99.6819  Kaggle

# %%
airports['CITY_STATE'] = airports['CITY']+'-'+airports['STATE']

# %%
airports.head(2)
# Out:
#   IATA_CODE                              AIRPORT       CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport  Allentown    PA     USA
# 1       ABI             Abilene Regional Airport    Abilene    TX     USA
#
#    LATITUDE  LONGITUDE  SOURCE    CITY_STATE
# 0  40.65236   -75.4404  Kaggle  Allentown-PA
# 1  32.41132   -99.6819  Kaggle    Abilene-TX

# %%
airports.head(5)
# Out:
#   IATA_CODE                              AIRPORT         CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport    Allentown    PA     USA
# 1       ABI             Abilene Regional Airport      Abilene    TX     USA
# 2       ABQ    Albuquerque International Sunport  Albuquerque    NM     USA
# 3       ABR            Aberdeen Regional Airport     Aberdeen    SD     USA
# 4       ABY   Southwest Georgia Regional Airport       Albany    GA     USA
#
#    LATITUDE  LONGITUDE  SOURCE      CITY_STATE
# 0  40.65236  -75.44040  Kaggle    Allentown-PA
# 1  32.41132  -99.68190  Kaggle      Abilene-TX
# 2  35.04022 -106.60919  Kaggle  Albuquerque-NM
# 3  45.44906  -98.42183  Kaggle     Aberdeen-SD
# 4  31.53552  -84.19447  Kaggle       Albany-GA

# %%
airports.sort_values('STATE').head(5)
# Out:
#     IATA_CODE                                      AIRPORT         CITY STATE  \
# 108       FAI              Fairbanks International Airport    Fairbanks    AK
# 17        ANC  Ted Stevens Anchorage International Airport    Anchorage    AK
# 89        DLG                           Dillingham Airport   Dillingham    AK
# 320       YAK                              Yakutat Airport      Yakutat    AK
# 13        AKN                          King Salmon Airport  King Salmon    AK
#
#     COUNTRY  LATITUDE  LONGITUDE  SOURCE      CITY_STATE
# 108     USA  64.81368 -147.85967  Kaggle    Fairbanks-AK
# 17      USA  61.17432 -149.99619  Kaggle    Anchorage-AK
# 89      USA  59.04541 -158.50334  Kaggle   Dillingham-AK
# 320     USA  59.50336 -139.66023  Kaggle      Yakutat-AK
# 13      USA  58.67680 -156.64922  Kaggle  King Salmon-AK

# %%
airports.sort_values('AIRPORT').head(5)
# Out:
#     IATA_CODE                          AIRPORT         CITY STATE COUNTRY  \
# 3         ABR        Aberdeen Regional Airport     Aberdeen    SD     USA
# 1         ABI         Abilene Regional Airport      Abilene    TX     USA
# 290       SPI  Abraham Lincoln Capital Airport  Springfield    IL     USA
# 9         ADK                     Adak Airport         Adak    AK     USA
# 54        CAK    Akron-Canton Regional Airport        Akron    OH     USA
#
#      LATITUDE  LONGITUDE  SOURCE      CITY_STATE
# 3    45.44906  -98.42183  Kaggle     Aberdeen-SD
# 1    32.41132  -99.68190  Kaggle      Abilene-TX
# 290  39.84395  -89.67762  Kaggle  Springfield-IL
# 9    51.87796 -176.64603  Kaggle         Adak-AK
# 54   40.91631  -81.44247  Kaggle        Akron-OH

# %%
airports_index = airports.set_index('STATE')
airports_index.head(2)
# Out:
#       IATA_CODE                              AIRPORT       CITY COUNTRY  \
# STATE
# PA          ABE  Lehigh Valley International Airport  Allentown     USA
# TX          ABI             Abilene Regional Airport    Abilene     USA
#
#        LATITUDE  LONGITUDE  SOURCE    CITY_STATE
# STATE
# PA     40.65236   -75.4404  Kaggle  Allentown-PA
# TX     32.41132   -99.6819  Kaggle    Abilene-TX

# %%
airports_index.loc['AK'].head(2)
# Out:
#       IATA_CODE         AIRPORT    CITY COUNTRY  LATITUDE  LONGITUDE  SOURCE  \
# STATE
# AK          ADK    Adak Airport    Adak     USA  51.87796 -176.64603  Kaggle
# AK          ADQ  Kodiak Airport  Kodiak     USA  57.74997 -152.49386  Kaggle
#
#       CITY_STATE
# STATE
# AK       Adak-AK
# AK     Kodiak-AK

# %%
airports_index.loc['AK', ['CITY']].head(2)
# Out:
#          CITY
# STATE
# AK       Adak
# AK     Kodiak

# %%
airports_index.loc[['PA', 'AK'], ['CITY', 'COUNTRY']].head(2)
# Out:
#                         CITY COUNTRY
# STATE
# PA                 Allentown     USA
# PA     Wilkes-Barre/Scranton     USA

# %%
airports_index.loc[airports_index['CITY']=='Los Angeles'].head(2)
# Out:
#       IATA_CODE                            AIRPORT         CITY COUNTRY  \
# STATE
# CA          LAX  Los Angeles International Airport  Los Angeles     USA
#
#        LATITUDE  LONGITUDE  SOURCE      CITY_STATE
# STATE
# CA     33.94254 -118.40807  Kaggle  Los Angeles-CA

# %%
airports_index[airports_index['CITY']=='Los Angeles'].head(2)
# Out:
#       IATA_CODE                            AIRPORT         CITY COUNTRY  \
# STATE
# CA          LAX  Los Angeles International Airport  Los Angeles     USA
#
#        LATITUDE  LONGITUDE  SOURCE      CITY_STATE
# STATE
# CA     33.94254 -118.40807  Kaggle  Los Angeles-CA

# %%
flights[['ARRIVAL_TIME', 'ARRIVAL_DELAY']].head(2)
# Out:
#    ARRIVAL_TIME  ARRIVAL_DELAY
# 0         408.0          -22.0
# 1         741.0           -9.0

# %%
flights['rank'] = flights['ARRIVAL_TIME'].rank(method='max')

flights[['ARRIVAL_TIME', 'ARRIVAL_DELAY', 'rank']].head(2)
# Out:
#    ARRIVAL_TIME  ARRIVAL_DELAY     rank
# 0         408.0          -22.0  19016.0
# 1         741.0           -9.0  56766.0

# %%
flights[['ARRIVAL_TIME', 'ARRIVAL_DELAY', 'rank']].sort_values('rank', ascending=False).head(2)
# Out:
#        ARRIVAL_TIME  ARRIVAL_DELAY      rank
# 45032        2400.0           80.0  959117.0
# 59345        2400.0          135.0  959117.0

# %%
airports.head(2)
# Out:
#   IATA_CODE                              AIRPORT       CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport  Allentown    PA     USA
# 1       ABI             Abilene Regional Airport    Abilene    TX     USA
#
#    LATITUDE  LONGITUDE  SOURCE    CITY_STATE
# 0  40.65236   -75.4404  Kaggle  Allentown-PA
# 1  32.41132   -99.6819  Kaggle    Abilene-TX

# %%
airports.rename(columns={'AIRPORT':'AIRPORT_NAME'}).head(2)
# Out:
#   IATA_CODE                         AIRPORT_NAME       CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport  Allentown    PA     USA
# 1       ABI             Abilene Regional Airport    Abilene    TX     USA
#
#    LATITUDE  LONGITUDE  SOURCE    CITY_STATE
# 0  40.65236   -75.4404  Kaggle  Allentown-PA
# 1  32.41132   -99.6819  Kaggle    Abilene-TX
